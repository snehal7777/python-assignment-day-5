# %%
#question2
def isPrime(x): 
for n in range(2,x): 
if x%n==0: 
return False else: 
return True 
fltrObj=filter(isPrime, range(2500))
 print ('Prime numbers between 1-2500:',
 
 
#quesstion3
txt = "hey this is sai", im from mumbai. 
 
x = txt.capitalize()
 
print (x)
# Out:
#   File "<ipython-input-1-2c3877df5db1>", line 3
#     for n in range(2,x):
#       ^
# IndentationError: expected an indented block
